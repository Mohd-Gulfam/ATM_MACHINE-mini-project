# %% [markdown]
# <a href="https://colab.research.google.com/github/Mohd-Gulfam/ATM_MACHINE-mini-project/blob/main/speechToText.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# create speech to text converter using whisper model and upload the code on github
